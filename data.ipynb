# %% [markdown]
# UPLOADING DATASETS INTO GOOGLE COLAB

# %% [markdown]
# To start, we need to import the relevant libraries and upload our datasets.

# %%
# !mkdir analysis #creates a folder to put all the datasets

# %%
import pandas as pd #imports a library so we can conduct statistical analysis 
from google.colab import files #allows us to import a file 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cd7de9b0-2bfb-49f9-9c10-6e33b39d5b7d" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cd7de9b0-2bfb-49f9-9c10-6e33b39d5b7d">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>

# %%
import io
df1 = pd.read_csv(io.BytesIO(uploaded['popqualifications.csv'])) #giving the dataset a name
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-73b4ee306e5e> in <module>()
#       1 import io
# ----> 2 df1 = pd.read_csv(io.BytesIO(uploaded['popqualifications.csv'])) #giving the dataset a name
#
# NameError: name 'pd' is not defined

# %% [markdown]
# Now that the dataset has been imported, we can see its contents. This dataset shows the % of people without qualifications between 2015-2017, as well as the mean across the years.
#
# We will be using the **mean** since we need one value for each borough.

# %%
df1
# Out:
#                    Borough  ...  av 2015-2017
# 0     Barking and Dagenham  ...     14.133333
# 1                   Barnet  ...      5.066667
# 2                   Bexley  ...      7.333333
# 3                    Brent  ...      7.033333
# 4                  Bromley  ...      3.766667
# 5                   Camden  ...      7.433333
# 6                  Croydon  ...      5.633333
# 7                   Ealing  ...      6.933333
# 8                  Enfield  ...      6.500000
# 9                Greenwich  ...      7.700000
# 10                 Hackney  ...      9.100000
# 11  Hammersmith and Fulham  ...      4.800000
# 12                Haringey  ...      8.966667
# 13                  Harrow  ...      3.366667
# 14                Havering  ...      9.000000
# 15              Hillingdon  ...      7.600000
# 16                Hounslow  ...      6.600000
# 17               Islington  ...      6.933333
# 18  Kensington and Chelsea  ...      4.233333
# 19    Kingston upon Thames  ...      4.100000
# 20                 Lambeth  ...      5.600000
# 21                Lewisham  ...      4.600000
# 22                  Merton  ...      4.600000
# 23                  Newham  ...     11.800000
# 24               Redbridge  ...      8.966667
# 25    Richmond upon Thames  ...      2.166667
# 26               Southwark  ...      7.033333
# 27                  Sutton  ...      5.633333
# 28           Tower Hamlets  ...     12.133333
# 29          Waltham Forest  ...      9.966667
# 30              Wandsworth  ...      3.366667
# 31             Westminster  ...      4.933333
#
# [32 rows x 5 columns]

# %%
df1.describe()  #used to get summary statistics for a datset
# Out:
#        2015: % of people aged 25-64 with no qualifications  ...  av 2015-2017
# count                                          32.000000    ...     32.000000
# mean                                            7.371875    ...      6.782292
# std                                             2.910740    ...      2.733438
# min                                             2.700000    ...      2.166667
# 25%                                             4.775000    ...      4.750000
# 50%                                             6.850000    ...      6.766667
# 75%                                            10.225000    ...      8.016667
# max                                            12.400000    ...     14.133333
#
# [8 rows x 4 columns]

# %%
df1.mean() #used to get averages for the dataset
# Out:
# 2015: % of people aged 25-64 with no qualifications    7.371875
# 2016: % of people aged 25-64 with no qualifications    6.468750
# 2017: % of people aged 25-64 with no qualifications    6.506250
# av 2015-2017                                           6.782292
# dtype: float64

# %%
clean1 = df1[['Borough','av 2015-2017']] #used to look at a particular part of the dataset 
clean1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-081064eee608> in <module>()
# ----> 1 clean1 = df1[['Borough','av 2015-2017']] #used to look at a particular part of the dataset
#       2 clean1
#
# NameError: name 'df1' is not defined

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-864b4a32-02cf-43e4-816e-783a2d757c7c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-864b4a32-02cf-43e4-816e-783a2d757c7c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving incomedeprivation1.csv to incomedeprivation1.csv

# %% [markdown]
# Now, we are uploading the dataset for income deprivation. Just like we did above, we can look at the dataset and will take the average values over the years. In this case, it's between 2015-2019 instead.

# %%
import io
df2 = pd.read_csv(io.BytesIO(uploaded['incomedeprivation1.csv']))
df2
# Out:
#                    Borough  ...  av imd 2015-2019
# 0     Barking and Dagenham  ...              17.4
# 1                   Barnet  ...               9.0
# 2                   Bexley  ...               8.1
# 3                    Brent  ...              13.4
# 4                  Bromley  ...               7.6
# 5                   Camden  ...              12.5
# 6                  Croydon  ...              11.9
# 7                   Ealing  ...              11.8
# 8                  Enfield  ...              13.6
# 9                Greenwich  ...              12.9
# 10                 Hackney  ...              17.7
# 11  Hammersmith and Fulham  ...              12.2
# 12                Haringey  ...              15.6
# 13                  Harrow  ...               7.2
# 14                Havering  ...               9.0
# 15              Hillingdon  ...               9.1
# 16                Hounslow  ...              11.3
# 17               Islington  ...              16.4
# 18  Kensington and Chelsea  ...              11.7
# 19    Kingston upon Thames  ...               5.6
# 20                 Lambeth  ...              14.6
# 21                Lewisham  ...              14.4
# 22                  Merton  ...               7.5
# 23                  Newham  ...              16.6
# 24               Redbridge  ...              10.2
# 25    Richmond upon Thames  ...               5.1
# 26               Southwark  ...              14.8
# 27                  Sutton  ...               7.3
# 28           Tower Hamlets  ...              17.9
# 29          Waltham Forest  ...              15.2
# 30              Wandsworth  ...               9.2
# 31             Westminster  ...              13.9
# 32                     NaN  ...               NaN
# 33                     NaN  ...               NaN
#
# [34 rows x 4 columns]

# %%
clean2 = df2[['Borough', 'av imd 2015-2019']]
clean2
# Out:
#                    Borough  av imd 2015-2019
# 0     Barking and Dagenham              17.4
# 1                   Barnet               9.0
# 2                   Bexley               8.1
# 3                    Brent              13.4
# 4                  Bromley               7.6
# 5                   Camden              12.5
# 6                  Croydon              11.9
# 7                   Ealing              11.8
# 8                  Enfield              13.6
# 9                Greenwich              12.9
# 10                 Hackney              17.7
# 11  Hammersmith and Fulham              12.2
# 12                Haringey              15.6
# 13                  Harrow               7.2
# 14                Havering               9.0
# 15              Hillingdon               9.1
# 16                Hounslow              11.3
# 17               Islington              16.4
# 18  Kensington and Chelsea              11.7
# 19    Kingston upon Thames               5.6
# 20                 Lambeth              14.6
# 21                Lewisham              14.4
# 22                  Merton               7.5
# 23                  Newham              16.6
# 24               Redbridge              10.2
# 25    Richmond upon Thames               5.1
# 26               Southwark              14.8
# 27                  Sutton               7.3
# 28           Tower Hamlets              17.9
# 29          Waltham Forest              15.2
# 30              Wandsworth               9.2
# 31             Westminster              13.9
# 32                     NaN               NaN
# 33                     NaN               NaN

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-a4f99335-5252-46ed-9101-9181e7361db6" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-a4f99335-5252-46ed-9101-9181e7361db6">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving ethnicity1.csv to ethnicity1.csv

# %%
import io
df3 = pd.read_csv(io.BytesIO(uploaded['ethnicity1.csv']))
df3
# Out:
#                    Borough 2015 white  ... av black  av mixed/other
# 0     Barking and Dagenham     95,000  ...    46,667          14,667
# 1                   Barnet    247,000  ...    21,667          49,000
# 2                   Bexley    195,000  ...    25,667           6,667
# 3                    Brent    108,000  ...    56,333          47,667
# 4                  Bromley    259,000  ...    24,000          19,000
# 5                   Camden    158,000  ...    25,000          35,667
# 6                  Croydon    221,000  ...    66,667          28,667
# 7                   Ealing    160,000  ...    31,667          45,000
# 8                  Enfield    192,000  ...    58,333          33,000
# 9                Greenwich    170,000  ...    54,667          17,667
# 10                 Hackney    145,000  ...    50,667          48,000
# 11  Hammersmith and Fulham    119,000  ...    24,667          17,333
# 12                Haringey    164,000  ...    41,667          38,000
# 13                  Harrow    103,000  ...    12,333          20,333
# 14                Havering    217,000  ...    11,000           9,667
# 15              Hillingdon    159,000  ...    25,000          25,667
# 16                Hounslow    128,000  ...    20,000          27,333
# 17               Islington    151,000  ...    26,333          35,333
# 18  Kensington and Chelsea    104,000  ...    16,333          25,000
# 19    Kingston upon Thames    130,000  ...     4,000          17,000
# 20                 Lambeth    199,000  ...    71,000          28,667
# 21                Lewisham    161,000  ...    68,333          23,667
# 22                  Merton    134,000  ...    20,333          17,333
# 23                  Newham    107,000  ...    55,333          35,667
# 24               Redbridge    123,000  ...    22,000          17,333
# 25    Richmond upon Thames    166,000  ...     3,333          13,000
# 26               Southwark    165,000  ...    74,000          35,667
# 27                  Sutton    152,000  ...    11,667          14,667
# 28           Tower Hamlets    109,000  ...    23,333          19,667
# 29          Waltham Forest    140,000  ...    42,333          26,333
# 30              Wandsworth    233,000  ...    22,667          29,667
# 31             Westminster    132,000  ...    21,000          50,667
#
# [32 rows x 17 columns]

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-d627fc1f-09c3-4fb8-8f6b-3d41c2f3eab3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-d627fc1f-09c3-4fb8-8f6b-3d41c2f3eab3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving particpationdatasplit1.csv to particpationdatasplit1.csv

# %% [markdown]
# CAN WE CLEAN THE DATASET BELOW TO GET RID OF THE'UNNAMED' COLUMNS?

# %%
import io
df5 = pd.read_csv(io.BytesIO(uploaded['particpationdatasplit1.csv']))
df5
# Out:
#                    Borough  ...  Unnamed: 10
# 0     Barking and Dagenham  ...          NaN
# 1                   Barnet  ...          NaN
# 2                   Bexley  ...          NaN
# 3                    Brent  ...          NaN
# 4                  Bromley  ...          NaN
# 5                   Camden  ...          NaN
# 6                  Croydon  ...          NaN
# 7                   Ealing  ...          NaN
# 8                  Enfield  ...          NaN
# 9                Greenwich  ...          NaN
# 10                 Hackney  ...          NaN
# 11  Hammersmith and Fulham  ...          NaN
# 12                Haringey  ...          NaN
# 13                  Harrow  ...          NaN
# 14                Havering  ...          NaN
# 15              Hillingdon  ...          NaN
# 16                Hounslow  ...          NaN
# 17               Islington  ...          NaN
# 18  Kensington and Chelsea  ...          NaN
# 19    Kingston upon Thames  ...          NaN
# 20                 Lambeth  ...          NaN
# 21                Lewisham  ...          NaN
# 22                  Merton  ...          NaN
# 23                  Newham  ...          NaN
# 24               Redbridge  ...          NaN
# 25    Richmond upon Thames  ...          NaN
# 26               Southwark  ...          NaN
# 27                  Sutton  ...          NaN
# 28           Tower Hamlets  ...          NaN
# 29          Waltham Forest  ...          NaN
# 30              Wandsworth  ...          NaN
# 31             Westminster  ...          NaN
#
# [32 rows x 11 columns]

# %%
df_joined = df3.merge(df5, left_index=True, right_index=True) #decides what datasets to merge and where to merge the datasets
df_joined
# Out:
#                  Borough_x 2015 white  ... Unnamed: 9 Unnamed: 10
# 0     Barking and Dagenham     95,000  ...        NaN         NaN
# 1                   Barnet    247,000  ...        NaN         NaN
# 2                   Bexley    195,000  ...        NaN         NaN
# 3                    Brent    108,000  ...        NaN         NaN
# 4                  Bromley    259,000  ...        NaN         NaN
# 5                   Camden    158,000  ...        NaN         NaN
# 6                  Croydon    221,000  ...        NaN         NaN
# 7                   Ealing    160,000  ...        NaN         NaN
# 8                  Enfield    192,000  ...        NaN         NaN
# 9                Greenwich    170,000  ...        NaN         NaN
# 10                 Hackney    145,000  ...        NaN         NaN
# 11  Hammersmith and Fulham    119,000  ...        NaN         NaN
# 12                Haringey    164,000  ...        NaN         NaN
# 13                  Harrow    103,000  ...        NaN         NaN
# 14                Havering    217,000  ...        NaN         NaN
# 15              Hillingdon    159,000  ...        NaN         NaN
# 16                Hounslow    128,000  ...        NaN         NaN
# 17               Islington    151,000  ...        NaN         NaN
# 18  Kensington and Chelsea    104,000  ...        NaN         NaN
# 19    Kingston upon Thames    130,000  ...        NaN         NaN
# 20                 Lambeth    199,000  ...        NaN         NaN
# 21                Lewisham    161,000  ...        NaN         NaN
# 22                  Merton    134,000  ...        NaN         NaN
# 23                  Newham    107,000  ...        NaN         NaN
# 24               Redbridge    123,000  ...        NaN         NaN
# 25    Richmond upon Thames    166,000  ...        NaN         NaN
# 26               Southwark    165,000  ...        NaN         NaN
# 27                  Sutton    152,000  ...        NaN         NaN
# 28           Tower Hamlets    109,000  ...        NaN         NaN
# 29          Waltham Forest    140,000  ...        NaN         NaN
# 30              Wandsworth    233,000  ...        NaN         NaN
# 31             Westminster    132,000  ...        NaN         NaN
#
# [32 rows x 28 columns]

# %%
df3_joined = df2.merge(df5, left_index=True, right_index=True) 
df3_joined
# Out:
#                  Borough_x  2015 IMD AV SCORE   ...  Unnamed: 9  Unnamed: 10
# 0     Barking and Dagenham                34.6  ...         NaN          NaN
# 1                   Barnet                17.8  ...         NaN          NaN
# 2                   Bexley                16.2  ...         NaN          NaN
# 3                    Brent                26.7  ...         NaN          NaN
# 4                  Bromley                15.2  ...         NaN          NaN
# 5                   Camden                25.0  ...         NaN          NaN
# 6                  Croydon                23.6  ...         NaN          NaN
# 7                   Ealing                23.6  ...         NaN          NaN
# 8                  Enfield                27.0  ...         NaN          NaN
# 9                Greenwich                25.5  ...         NaN          NaN
# 10                 Hackney                35.3  ...         NaN          NaN
# 11  Hammersmith and Fulham                24.4  ...         NaN          NaN
# 12                Haringey                31.0  ...         NaN          NaN
# 13                  Harrow                14.3  ...         NaN          NaN
# 14                Havering                17.9  ...         NaN          NaN
# 15              Hillingdon                18.1  ...         NaN          NaN
# 16                Hounslow                22.5  ...         NaN          NaN
# 17               Islington                32.5  ...         NaN          NaN
# 18  Kensington and Chelsea                23.4  ...         NaN          NaN
# 19    Kingston upon Thames                11.1  ...         NaN          NaN
# 20                 Lambeth                28.9  ...         NaN          NaN
# 21                Lewisham                28.6  ...         NaN          NaN
# 22                  Merton                14.9  ...         NaN          NaN
# 23                  Newham                32.9  ...         NaN          NaN
# 24               Redbridge                20.2  ...         NaN          NaN
# 25    Richmond upon Thames                10.0  ...         NaN          NaN
# 26               Southwark                29.5  ...         NaN          NaN
# 27                  Sutton                14.6  ...         NaN          NaN
# 28           Tower Hamlets                35.7  ...         NaN          NaN
# 29          Waltham Forest                30.2  ...         NaN          NaN
# 30              Wandsworth                18.3  ...         NaN          NaN
# 31             Westminster                27.7  ...         NaN          NaN
#
# [32 rows x 15 columns]

# %%
clean4 = df3_joined[['Used a public library service','av imd 2015-2019']] #getting a specific part of the dataset for analysis as there are repeats 
clean4
# Out:
#     Used a public library service  av imd 2015-2019
# 0                           33.82              17.4
# 1                           37.24               9.0
# 2                           40.01               8.1
# 3                           37.60              13.4
# 4                           41.01               7.6
# 5                           44.83              12.5
# 6                           40.95              11.9
# 7                           37.59              11.8
# 8                           38.59              13.6
# 9                           42.67              12.9
# 10                          40.92              17.7
# 11                          32.24              12.2
# 12                          40.86              15.6
# 13                          36.62               7.2
# 14                          33.43               9.0
# 15                          47.99               9.1
# 16                          36.03              11.3
# 17                          44.48              16.4
# 18                          41.46              11.7
# 19                          36.27               5.6
# 20                          38.67              14.6
# 21                          45.24              14.4
# 22                          38.92               7.5
# 23                          35.96              16.6
# 24                          42.91              10.2
# 25                          45.84               5.1
# 26                          43.24              14.8
# 27                          39.06               7.3
# 28                          39.20              17.9
# 29                          41.97              15.2
# 30                          40.39               9.2
# 31                          41.96              13.9

# %% [markdown]
# Scatter graph: the impact of deprivation on the use of free cultural infrastructure

# %%
correlate = clean4.corr() #produces a correlation matrix 
correlate
# Out:
#                                Used a public library service  av imd 2015-2019
# Used a public library service                       1.000000          0.006707
# av imd 2015-2019                                    0.006707          1.000000

# %%
clean4.describe()
# Out:
#        Used a public library service  av imd 2015-2019
# count                      32.000000         32.000000
# mean                       39.936563         11.896875
# std                         3.736959          3.663551
# min                        32.240000          5.100000
# 25%                        37.502500          9.000000
# 50%                        40.200000         12.050000
# 75%                        42.145000         14.650000
# max                        47.990000         17.900000

# %%
clean4.mean()
# Out:
# Used a public library service    39.936563
# av imd 2015-2019                 11.896875
# dtype: float64

# %%
clean4.kurtosis() #kurtosis
# Out:
# Used a public library service   -0.279152
# av imd 2015-2019                -1.014728
# dtype: float64

# %%
#Imported numerous libraries into Google Colab 
# %matplotlib inline 
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np

# %%
x = clean4['av imd 2015-2019'] #decides the x values 
y = clean4['Used a public library service'] #decides the y values 
plt.xlabel("Average index of multiple deprivation for London Boroughs 2015-2019") #axis label for x 
plt.ylabel("Used a public library service 2015-2017") #axis label for x 
plt.scatter(x,y); #plots scatterplot

# %%
from sklearn.linear_model import LinearRegression #imports statistical tool 
model = LinearRegression(fit_intercept=True)

model.fit(x[:, np.newaxis], y) #fits the linear model 

xfit = np.linspace(0,18,50) #sets the size 
yfit = model.predict(xfit[:, np.newaxis])

plt.xlabel("Average index of multiple deprivation for London Boroughs 2015-2019")
plt.ylabel("Used a public library service 2015-2017")

plt.scatter(x,y)
plt.plot(xfit, yfit);
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: FutureWarning: Support for multi-dimensional indexing (e.g. `obj[:, None]`) is deprecated and will be removed in a future version.  Convert to a numpy array before indexing instead.
#   after removing the cwd from sys.path.

# %%
print("Model slope: ", model.coef_[0]) #produces a numerical value of the coefficient for the linear regression 
print("Model intercept:", model.intercept_) #produces a numerical value of the intercept of the linear regression
# Out:
# Model slope:  0.006841777556794478
# Model intercept: 39.85516672762902

# %% [markdown]
# Correlation matrix

# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-594a645a-2162-4be7-ae55-1ead5f52ee7a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-594a645a-2162-4be7-ae55-1ead5f52ee7a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving heatmap.csv to heatmap.csv

# %%
import io
df20 = pd.read_csv(io.BytesIO(uploaded['heatmap.csv']))

# %%
df20
corr10 = df20.corr()
corr10
# Out:
#                                                     Creative, artistic, theatrical or musical activty or craft  ...  Mixed and other
# Creative, artistic, theatrical or musical activ...                                           1.000000           ...          0.246724
# event, performance or festival                                                               0.862448           ...          0.106318
# Museum or gallery                                                                            0.879707           ...          0.241398
# Dance                                                                                        0.771075           ...          0.377061
# Public library service                                                                       0.383975           ...          0.115540
# No qualifications                                                                           -0.361267           ...          0.028823
# Deprivation                                                                                  0.194443           ...          0.455836
# White                                                                                        0.059778           ...          0.035708
# Asian                                                                                       -0.390384           ...          0.168616
# Black                                                                                        0.103214           ...          0.349334
# Mixed and other                                                                              0.246724           ...          1.000000
#
# [11 rows x 11 columns]

# %% [markdown]
# Heatmap

# %%
# %matplotlib inline 
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()
import numpy as np

# %%
mask = np.zeros_like(corr10, dtype=np.bool) #ignores the top triangle of the correlation matrix 
mask[np.triu_indices_from(mask)]= True

# %%
f, ax = plt.subplots(figsize=(15, 15))
heatmap = sns.heatmap(corr10,mask = mask, cmap="coolwarm", square = True, linewidths = .5, cbar_kws = {'shrink': .4}, vmin = -1, vmax = 1, annot = True, annot_kws = {'size': 15})

# %%
f, ax = plt.subplots(figsize=(15, 15)) #sets the figure size
heatmap = sns.heatmap(corr6,mask = mask,  #ignores any invalid values 
cmap=”coolwarm’ #sets the colour
 square = True,  #sets the shape 
 linewidths = .5,  #sets the width of the lines
cbar_kws = {'shrink': .4},  #sets the label size 
vmin = -1, vmax = 1, #sets the minimum and maximum colour bar value
annot = True, #sets the annotations for the values in the correlation matrix 
 annot_kws = {'size': 15}) #sets the annotation size
